# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from dataclasses import dataclass
from langchain.agents.middleware import dynamic_prompt, ModelRequest

@dataclass
class LanguageContext:
    user_language: str = "English"

@dynamic_prompt
def user_language_prompt(request: ModelRequest) -> str:
    """Generate system prompt based on user role."""
    user_language = request.runtime.context.user_language
    base_prompt = "You are a helpful assistant."

    if user_language != "English":
        return f"{base_prompt} only respond in {user_language}."
    elif user_language == "English":
        return base_prompt

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    context_schema=LanguageContext,
    middleware=[user_language_prompt]
)

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="Irish")
)

print(response["messages"][-1].content)
# Out:
# Dia dhuit! Tá mé go maith, go raibh maith agat. Conas atá tú féin?

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="HOla, puedes ayudarme con mi tarea?")]},
    context=LanguageContext(user_language="Spanish")
)

print(response["messages"][-1].content)
# Out:
# ¡Claro! ¿De qué tema es tu tarea y qué nivel tienes? (por ejemplo: matemáticas de secundaria, historia del bachillerato, etc.)
#
# Para ayudarte mejor, dime:
# - La materia y el tema.
# - El formato de la tarea (preguntas, ensayo, problemas para resolver, etc.).
# - Tu nivel y la fecha límite, si la hay.
# - Si puedes pegar el enunciado; así te explico paso a paso o te ayudo a resolverlo.
#
# Puedo: explicar conceptos, resolver ejercicios paso a paso, revisar respuestas, hacer un resumen o un esquema, y darte ideas para un ensayo. ¿Con qué empezamos?

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Hello, how are you?")]},
    context=LanguageContext(user_language="French")
)

print(response["messages"][-1].content)
# Out:
# Bonjour ! Je vais bien, merci. Et vous, comment allez-vous ?
